# %%
import nltk
from nltk.tag import pos_tag
nltk.download('averaged_perceptron_tagger_eng')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /Users/pranjalparmar/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /Users/pranjalparmar/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
paragraph = '''I have three visions for India. In 3000 years of our history people from all over the world have come and invaded us, captured our lands, conquered our minds. From Alexander onwards the Greeks, the Turks, the Moguls, the Portuguese, the British, the French, the Dutch, all of them came and looted us, took over what was ours. Yet we have not done this to any other nation. We have not conquered anyone. We have not grabbed their land, their culture and their history and tried to enforce our way of life on them. Why? Because we respect the freedom of others. That is why my FIRST VISION is that of FREEDOM. I believe that India got its first vision of this in 1857, when we started the war of Independence. It is this freedom that we must protect and nurture and build on. If we are not free, no one will respect us.

We have 10 percent growth rate in most areas. Our poverty levels are falling. Our achievements are being globally recognised today. Yet we lack the self-confidence to see ourselves as a developed nation, self-reliant and self-assured. Isn’t this incorrect? MY SECOND VISION for India is DEVELOPMENT. For fifty years we have been a developing nation. It is time we see ourselves as a developed nation. We are among top five nations in the world in terms of GDP.

I have a THIRD VISION. India must stand up to the world. Because I believe that unless India stands up to the world, no one will respect us. Only strength respects strength. We must be strong not only as a military power but also as an economic power. Both must go hand-in-hand. My good fortune was to have worked with three great minds. Dr.Vikram Sarabhai, of the Dept. of Space, Professor Satish Dhawan, who succeeded him and Dr. Brahm Prakash, father of nuclear material. I was lucky to have worked with all three of them closely and consider this the great opportunity of my life.

I was in Hyderabad giving this lecture, when a 14 year-old girl asked me for my autograph. I asked her what her goal in life is. She replied: I want to live in a developed India. For her, you and I will have to build this developed India. You must proclaim India is not an underdeveloped nation; it is a highly developed nation.

You say that our government is inefficient. You say that our laws are too old. You say that the municipality does not pick up the garbage. You say that the phones don’t work, the railways are a joke, the airline is the worst in the world, and mails never reach their destination. You say that our country has been fed to the dogs and is the absolute pits. You say, say and say. What do you do about it?

Dear Indians, I am echoing J.F.Kennedy’s words to his fellow Americans to relate to Indians ……. “ASK WHAT WE CAN DO FOR INDIA AND DO WHAT HAS TO BE DONE TO MAKE INDIA WHAT AMERICA AND OTHER WESTERN COUNTRIES ARE TODAY.”'''

# %%
from nltk.tokenize import sent_tokenize
sentences = sent_tokenize(paragraph)

# %%
for i in sentences:
    print(i)
# Out:
# I have three visions for India.
# In 3000 years of our history people from all over the world have come and invaded us, captured our lands, conquered our minds.
# From Alexander onwards the Greeks, the Turks, the Moguls, the Portuguese, the British, the French, the Dutch, all of them came and looted us, took over what was ours.
# Yet we have not done this to any other nation.
# We have not conquered anyone.
# We have not grabbed their land, their culture and their history and tried to enforce our way of life on them.
# Why?
# Because we respect the freedom of others.
# That is why my FIRST VISION is that of FREEDOM.
# I believe that India got its first vision of this in 1857, when we started the war of Independence.
# It is this freedom that we must protect and nurture and build on.
# If we are not free, no one will respect us.
# We have 10 percent growth rate in most areas.
# Our poverty levels are falling.
# Our achievements are being globally recognised today.
# Yet we lack the self-confidence to see ourselves as a developed nation, self-reliant and self-assured.
# Isn’t this incorrect?
# MY SECOND VISION for India is DEVELOPMENT.
# For fifty years we have been a developing nation.
# It is time we see ourselves as a developed nation.
# We are among top five nations in the world in terms of GDP.
# I have a THIRD VISION.
# India must stand up to the world.
# Because I believe that unless India stands up to the world, no one will respect us.
# Only strength respects strength.
# We must be strong not only as a military power but also as an economic power.
# Both must go hand-in-hand.
# My good fortune was to have worked with three great minds.
# Dr.Vikram Sarabhai, of the Dept.
# of Space, Professor Satish Dhawan, who succeeded him and Dr. Brahm Prakash, father of nuclear material.
# I was lucky to have worked with all three of them closely and consider this the great opportunity of my life.
# I was in Hyderabad giving this lecture, when a 14 year-old girl asked me for my autograph.
# I asked her what her goal in life is.
# She replied: I want to live in a developed India.
# For her, you and I will have to build this developed India.
# You must proclaim India is not an underdeveloped nation; it is a highly developed nation.
# You say that our government is inefficient.
# You say that our laws are too old.
# You say that the municipality does not pick up the garbage.
# You say that the phones don’t work, the railways are a joke, the airline is the worst in the world, and mails never reach their destination.
# You say that our country has been fed to the dogs and is the absolute pits.
# You say, say and say.
# What do you do about it?
# Dear Indians, I am echoing J.F.Kennedy’s words to his fellow Americans to relate to Indians …….
# “ASK WHAT WE CAN DO FOR INDIA AND DO WHAT HAS TO BE DONE TO MAKE INDIA WHAT AMERICA AND OTHER WESTERN COUNTRIES ARE TODAY.”

# %%
from nltk.corpus import stopwords

# %%
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/pranjalparmar/nltk_data...
# True

# %%
for i in range(len(sentences)):
    words = nltk.word_tokenize(sentences[i])
    pos_tag = nltk.pos_tag(words)
    print(pos_tag)
    for word, tag in pos_tag:
        if tag == 'NNP' or tag == 'NNPS' or tag == 'NNS' or tag == 'NN':
            lemmatized_word = lemmatizer.lemmatize(word, 'n')
            print(f'Original Word: {word} --> Lemmatized Word: {lemmatized_word}')
        if tag == 'VB' or tag == 'VBD' or tag == 'VBG' or tag == 'VBN' or tag == 'VBP' or tag == 'VBZ':
            lemmatized_word = lemmatizer.lemmatize(word, 'v')
            print(f'Original Word: {word} --> Lemmatized Word: {lemmatized_word}')
        if tag == 'JJ' or tag == 'JJR' or tag == 'JJS':
            lemmatized_word = lemmatizer.lemmatize(word, 'a')
            print(f'Original Word: {word} --> Lemmatized Word: {lemmatized_word}')
        if tag == 'RB' or tag == 'RBR' or tag == 'RBS':
            lemmatized_word = lemmatizer.lemmatize(word, 'r')
            print(f'Original Word: {word} --> Lemmatized Word: {lemmatized_word}')
# Out:
# [('I', 'PRP'), ('have', 'VBP'), ('three', 'CD'), ('visions', 'NNS'), ('for', 'IN'), ('India', 'NNP'), ('.', '.')]
# Original Word: have --> Lemmatized Word: have
# Original Word: visions --> Lemmatized Word: vision
# Original Word: India --> Lemmatized Word: India
# [('In', 'IN'), ('3000', 'CD'), ('years', 'NNS'), ('of', 'IN'), ('our', 'PRP$'), ('history', 'NN'), ('people', 'NNS'), ('from', 'IN'), ('all', 'DT'), ('over', 'IN'), ('the', 'DT'), ('world', 'NN'), ('have', 'VBP'), ('come', 'VBN'), ('and', 'CC'), ('invaded', 'VBN'), ('us', 'PRP'), (',', ','), ('captured', 'VBD'), ('our', 'PRP$'), ('lands', 'NNS'), (',', ','), ('conquered', 'VBD'), ('our', 'PRP$'), ('minds', 'NNS'), ('.', '.')]
# Original Word: years --> Lemmatized Word: year
# Original Word: history --> Lemmatized Word: history
# Original Word: people --> Lemmatized Word: people
# Original Word: world --> Lemmatized Word: world
# Original Word: have --> Lemmatized Word: have
# Original Word: come --> Lemmatized Word: come
# Original Word: invaded --> Lemmatized Word: invade
# Original Word: captured --> Lemmatized Word: capture
# Original Word: lands --> Lemmatized Word: land
# Original Word: conquered --> Lemmatized Word: conquer
# Original Word: minds --> Lemmatized Word: mind
# [('From', 'IN'), ('Alexander', 'NNP'), ('onwards', 'IN'), ('the', 'DT'), ('Greeks', 'NNP'), (',', ','), ('the', 'DT'), ('Turks', 'NNP'), (',', ','), ('the', 'DT'), ('Moguls', 'NNP'), (',', ','), ('the', 'DT'), ('Portuguese', 'NNP'), (',', ','), ('the', 'DT'), ('British', 'JJ'), (',', ','), ('the', 'DT'), ('French', 'JJ'), (',', ','), ('the', 'DT'), ('Dutch', 'NNP'), (',', ','), ('all', 'DT'), ('of', 'IN'), ('them', 'PRP'), ('came', 'VBD'), ('and', 'CC'), ('looted', 'VBD'), ('us', 'PRP'), (',', ','), ('took', 'VBD'), ('over', 'RP'), ('what', 'WP'), ('was', 'VBD'), ('ours', 'PRP'), ('.', '.')]
# Original Word: Alexander --> Lemmatized Word: Alexander
# Original Word: Greeks --> Lemmatized Word: Greeks
# Original Word: Turks --> Lemmatized Word: Turks
# Original Word: Moguls --> Lemmatized Word: Moguls
# Original Word: Portuguese --> Lemmatized Word: Portuguese
# Original Word: British --> Lemmatized Word: British
# Original Word: French --> Lemmatized Word: French
# Original Word: Dutch --> Lemmatized Word: Dutch
# Original Word: came --> Lemmatized Word: come
# Original Word: looted --> Lemmatized Word: loot
# Original Word: took --> Lemmatized Word: take
# Original Word: was --> Lemmatized Word: be
# [('Yet', 'RB'), ('we', 'PRP'), ('have', 'VBP'), ('not', 'RB'), ('done', 'VBN'), ('this', 'DT'), ('to', 'TO'), ('any', 'DT'), ('other', 'JJ'), ('nation', 'NN'), ('.', '.')]
# Original Word: Yet --> Lemmatized Word: Yet
# Original Word: have --> Lemmatized Word: have
# Original Word: not --> Lemmatized Word: not
# Original Word: done --> Lemmatized Word: do
# Original Word: other --> Lemmatized Word: other
# Original Word: nation --> Lemmatized Word: nation
# [('We', 'PRP'), ('have', 'VBP'), ('not', 'RB'), ('conquered', 'VBN'), ('anyone', 'NN'), ('.', '.')]
# Original Word: have --> Lemmatized Word: have
# Original Word: not --> Lemmatized Word: not
# Original Word: conquered --> Lemmatized Word: conquer
# Original Word: anyone --> Lemmatized Word: anyone
# [('We', 'PRP'), ('have', 'VBP'), ('not', 'RB'), ('grabbed', 'VBN'), ('their', 'PRP$'), ('land', 'NN'), (',', ','), ('their', 'PRP$'), ('culture', 'NN'), ('and', 'CC'), ('their', 'PRP$'), ('history', 'NN'), ('and', 'CC'), ('tried', 'VBD'), ('to', 'TO'), ('enforce', 'VB'), ('our', 'PRP$'), ('way', 'NN'), ('of', 'IN'), ('life', 'NN'), ('on', 'IN'), ('them', 'PRP'), ('.', '.')]
# Original Word: have --> Lemmatized Word: have
# Original Word: not --> Lemmatized Word: not
# Original Word: grabbed --> Lemmatized Word: grab
# Original Word: land --> Lemmatized Word: land
# Original Word: culture --> Lemmatized Word: culture
# Original Word: history --> Lemmatized Word: history
# Original Word: tried --> Lemmatized Word: try
# Original Word: enforce --> Lemmatized Word: enforce
# Original Word: way --> Lemmatized Word: way
# Original Word: life --> Lemmatized Word: life
# [('Why', 'WRB'), ('?', '.')]
# [('Because', 'IN'), ('we', 'PRP'), ('respect', 'VBP'), ('the', 'DT'), ('freedom', 'NN'), ('of', 'IN'), ('others', 'NNS'), ('.', '.')]
# Original Word: respect --> Lemmatized Word: respect
# Original Word: freedom --> Lemmatized Word: freedom
# Original Word: others --> Lemmatized Word: others
# [('That', 'DT'), ('is', 'VBZ'), ('why', 'WRB'), ('my', 'PRP$'), ('FIRST', 'JJ'), ('VISION', 'NNP'), ('is', 'VBZ'), ('that', 'IN'), ('of', 'IN'), ('FREEDOM', 'NNP'), ('.', '.')]
# Original Word: is --> Lemmatized Word: be
# Original Word: FIRST --> Lemmatized Word: FIRST
# Original Word: VISION --> Lemmatized Word: VISION
# Original Word: is --> Lemmatized Word: be
# Original Word: FREEDOM --> Lemmatized Word: FREEDOM
# [('I', 'PRP'), ('believe', 'VBP'), ('that', 'IN'), ('India', 'NNP'), ('got', 'VBD'), ('its', 'PRP$'), ('first', 'JJ'), ('vision', 'NN'), ('of', 'IN'), ('this', 'DT'), ('in', 'IN'), ('1857', 'CD'), (',', ','), ('when', 'WRB'), ('we', 'PRP'), ('started', 'VBD'), ('the', 'DT'), ('war', 'NN'), ('of', 'IN'), ('Independence', 'NNP'), ('.', '.')]
# Original Word: believe --> Lemmatized Word: believe
# Original Word: India --> Lemmatized Word: India
# Original Word: got --> Lemmatized Word: get
# Original Word: first --> Lemmatized Word: first
# Original Word: vision --> Lemmatized Word: vision
# Original Word: started --> Lemmatized Word: start
# Original Word: war --> Lemmatized Word: war
# Original Word: Independence --> Lemmatized Word: Independence
# [('It', 'PRP'), ('is', 'VBZ'), ('this', 'DT'), ('freedom', 'NN'), ('that', 'IN'), ('we', 'PRP'), ('must', 'MD'), ('protect', 'VB'), ('and', 'CC'), ('nurture', 'NN'), ('and', 'CC'), ('build', 'VB'), ('on', 'IN'), ('.', '.')]
# Original Word: is --> Lemmatized Word: be
# Original Word: freedom --> Lemmatized Word: freedom
# Original Word: protect --> Lemmatized Word: protect
# Original Word: nurture --> Lemmatized Word: nurture
# Original Word: build --> Lemmatized Word: build
# [('If', 'IN'), ('we', 'PRP'), ('are', 'VBP'), ('not', 'RB'), ('free', 'JJ'), (',', ','), ('no', 'DT'), ('one', 'NN'), ('will', 'MD'), ('respect', 'VB'), ('us', 'PRP'), ('.', '.')]
# Original Word: are --> Lemmatized Word: be
# Original Word: not --> Lemmatized Word: not
# Original Word: free --> Lemmatized Word: free
# Original Word: one --> Lemmatized Word: one
# Original Word: respect --> Lemmatized Word: respect
# [('We', 'PRP'), ('have', 'VBP'), ('10', 'CD'), ('percent', 'JJ'), ('growth', 'NN'), ('rate', 'NN'), ('in', 'IN'), ('most', 'JJS'), ('areas', 'NNS'), ('.', '.')]
# Original Word: have --> Lemmatized Word: have
# Original Word: percent --> Lemmatized Word: percent
# Original Word: growth --> Lemmatized Word: growth
# Original Word: rate --> Lemmatized Word: rate
# Original Word: most --> Lemmatized Word: most
# Original Word: areas --> Lemmatized Word: area
# [('Our', 'PRP$'), ('poverty', 'NN'), ('levels', 'NNS'), ('are', 'VBP'), ('falling', 'VBG'), ('.', '.')]
# Original Word: poverty --> Lemmatized Word: poverty
# Original Word: levels --> Lemmatized Word: level
# Original Word: are --> Lemmatized Word: be
# Original Word: falling --> Lemmatized Word: fall
# [('Our', 'PRP$'), ('achievements', 'NNS'), ('are', 'VBP'), ('being', 'VBG'), ('globally', 'RB'), ('recognised', 'VBN'), ('today', 'NN'), ('.', '.')]
# Original Word: achievements --> Lemmatized Word: achievement
# Original Word: are --> Lemmatized Word: be
# Original Word: being --> Lemmatized Word: be
# Original Word: globally --> Lemmatized Word: globally
# Original Word: recognised --> Lemmatized Word: recognise
# Original Word: today --> Lemmatized Word: today
# [('Yet', 'CC'), ('we', 'PRP'), ('lack', 'VBP'), ('the', 'DT'), ('self-confidence', 'NN'), ('to', 'TO'), ('see', 'VB'), ('ourselves', 'PRP'), ('as', 'IN'), ('a', 'DT'), ('developed', 'JJ'), ('nation', 'NN'), (',', ','), ('self-reliant', 'JJ'), ('and', 'CC'), ('self-assured', 'JJ'), ('.', '.')]
# Original Word: lack --> Lemmatized Word: lack
# Original Word: self-confidence --> Lemmatized Word: self-confidence
# Original Word: see --> Lemmatized Word: see
# Original Word: developed --> Lemmatized Word: developed
# Original Word: nation --> Lemmatized Word: nation
# Original Word: self-reliant --> Lemmatized Word: self-reliant
# Original Word: self-assured --> Lemmatized Word: self-assured
# [('Isn', 'NNP'), ('’', 'NNP'), ('t', 'NN'), ('this', 'DT'), ('incorrect', 'NN'), ('?', '.')]
# Original Word: Isn --> Lemmatized Word: Isn
# Original Word: ’ --> Lemmatized Word: ’
# Original Word: t --> Lemmatized Word: t
# Original Word: incorrect --> Lemmatized Word: incorrect
# [('MY', 'PRP$'), ('SECOND', 'JJ'), ('VISION', 'NNP'), ('for', 'IN'), ('India', 'NNP'), ('is', 'VBZ'), ('DEVELOPMENT', 'NNP'), ('.', '.')]
# Original Word: SECOND --> Lemmatized Word: SECOND
# Original Word: VISION --> Lemmatized Word: VISION
# Original Word: India --> Lemmatized Word: India
# Original Word: is --> Lemmatized Word: be
# Original Word: DEVELOPMENT --> Lemmatized Word: DEVELOPMENT
# [('For', 'IN'), ('fifty', 'JJ'), ('years', 'NNS'), ('we', 'PRP'), ('have', 'VBP'), ('been', 'VBN'), ('a', 'DT'), ('developing', 'VBG'), ('nation', 'NN'), ('.', '.')]
# Original Word: fifty --> Lemmatized Word: fifty
# Original Word: years --> Lemmatized Word: year
# Original Word: have --> Lemmatized Word: have
# Original Word: been --> Lemmatized Word: be
# Original Word: developing --> Lemmatized Word: develop
# Original Word: nation --> Lemmatized Word: nation
# [('It', 'PRP'), ('is', 'VBZ'), ('time', 'NN'), ('we', 'PRP'), ('see', 'VBP'), ('ourselves', 'PRP'), ('as', 'IN'), ('a', 'DT'), ('developed', 'JJ'), ('nation', 'NN'), ('.', '.')]
# Original Word: is --> Lemmatized Word: be
# Original Word: time --> Lemmatized Word: time
# Original Word: see --> Lemmatized Word: see
# Original Word: developed --> Lemmatized Word: developed
# Original Word: nation --> Lemmatized Word: nation
# [('We', 'PRP'), ('are', 'VBP'), ('among', 'IN'), ('top', 'JJ'), ('five', 'CD'), ('nations', 'NNS'), ('in', 'IN'), ('the', 'DT'), ('world', 'NN'), ('in', 'IN'), ('terms', 'NNS'), ('of', 'IN'), ('GDP', 'NNP'), ('.', '.')]
# Original Word: are --> Lemmatized Word: be
# Original Word: top --> Lemmatized Word: top
# Original Word: nations --> Lemmatized Word: nation
# Original Word: world --> Lemmatized Word: world
# Original Word: terms --> Lemmatized Word: term
# Original Word: GDP --> Lemmatized Word: GDP
# [('I', 'PRP'), ('have', 'VBP'), ('a', 'DT'), ('THIRD', 'JJ'), ('VISION', 'NNP'), ('.', '.')]
# Original Word: have --> Lemmatized Word: have
# Original Word: THIRD --> Lemmatized Word: THIRD
# Original Word: VISION --> Lemmatized Word: VISION
# [('India', 'NNP'), ('must', 'MD'), ('stand', 'VB'), ('up', 'RP'), ('to', 'TO'), ('the', 'DT'), ('world', 'NN'), ('.', '.')]
# Original Word: India --> Lemmatized Word: India
# Original Word: stand --> Lemmatized Word: stand
# Original Word: world --> Lemmatized Word: world
# [('Because', 'IN'), ('I', 'PRP'), ('believe', 'VBP'), ('that', 'IN'), ('unless', 'IN'), ('India', 'NNP'), ('stands', 'VBZ'), ('up', 'RP'), ('to', 'TO'), ('the', 'DT'), ('world', 'NN'), (',', ','), ('no', 'DT'), ('one', 'NN'), ('will', 'MD'), ('respect', 'VB'), ('us', 'PRP'), ('.', '.')]
# Original Word: believe --> Lemmatized Word: believe
# Original Word: India --> Lemmatized Word: India
# Original Word: stands --> Lemmatized Word: stand
# Original Word: world --> Lemmatized Word: world
# Original Word: one --> Lemmatized Word: one
# Original Word: respect --> Lemmatized Word: respect
# [('Only', 'RB'), ('strength', 'NN'), ('respects', 'NNS'), ('strength', 'NN'), ('.', '.')]
# Original Word: Only --> Lemmatized Word: Only
# Original Word: strength --> Lemmatized Word: strength
# Original Word: respects --> Lemmatized Word: respect
# Original Word: strength --> Lemmatized Word: strength
# [('We', 'PRP'), ('must', 'MD'), ('be', 'VB'), ('strong', 'JJ'), ('not', 'RB'), ('only', 'RB'), ('as', 'IN'), ('a', 'DT'), ('military', 'JJ'), ('power', 'NN'), ('but', 'CC'), ('also', 'RB'), ('as', 'IN'), ('an', 'DT'), ('economic', 'JJ'), ('power', 'NN'), ('.', '.')]
# Original Word: be --> Lemmatized Word: be
# Original Word: strong --> Lemmatized Word: strong
# Original Word: not --> Lemmatized Word: not
# Original Word: only --> Lemmatized Word: only
# Original Word: military --> Lemmatized Word: military
# Original Word: power --> Lemmatized Word: power
# Original Word: also --> Lemmatized Word: also
# Original Word: economic --> Lemmatized Word: economic
# Original Word: power --> Lemmatized Word: power
# [('Both', 'DT'), ('must', 'MD'), ('go', 'VB'), ('hand-in-hand', 'NN'), ('.', '.')]
# Original Word: go --> Lemmatized Word: go
# Original Word: hand-in-hand --> Lemmatized Word: hand-in-hand
# [('My', 'PRP$'), ('good', 'JJ'), ('fortune', 'NN'), ('was', 'VBD'), ('to', 'TO'), ('have', 'VB'), ('worked', 'VBN'), ('with', 'IN'), ('three', 'CD'), ('great', 'JJ'), ('minds', 'NNS'), ('.', '.')]
# Original Word: good --> Lemmatized Word: good
# Original Word: fortune --> Lemmatized Word: fortune
# Original Word: was --> Lemmatized Word: be
# Original Word: have --> Lemmatized Word: have
# Original Word: worked --> Lemmatized Word: work
# Original Word: great --> Lemmatized Word: great
# Original Word: minds --> Lemmatized Word: mind
# [('Dr.Vikram', 'NNP'), ('Sarabhai', 'NNP'), (',', ','), ('of', 'IN'), ('the', 'DT'), ('Dept', 'NNP'), ('.', '.')]
# Original Word: Dr.Vikram --> Lemmatized Word: Dr.Vikram
# Original Word: Sarabhai --> Lemmatized Word: Sarabhai
# Original Word: Dept --> Lemmatized Word: Dept
# [('of', 'IN'), ('Space', 'NNP'), (',', ','), ('Professor', 'NNP'), ('Satish', 'NNP'), ('Dhawan', 'NNP'), (',', ','), ('who', 'WP'), ('succeeded', 'VBD'), ('him', 'PRP'), ('and', 'CC'), ('Dr.', 'NNP'), ('Brahm', 'NNP'), ('Prakash', 'NNP'), (',', ','), ('father', 'NN'), ('of', 'IN'), ('nuclear', 'JJ'), ('material', 'NN'), ('.', '.')]
# Original Word: Space --> Lemmatized Word: Space
# Original Word: Professor --> Lemmatized Word: Professor
# Original Word: Satish --> Lemmatized Word: Satish
# Original Word: Dhawan --> Lemmatized Word: Dhawan
# Original Word: succeeded --> Lemmatized Word: succeed
# Original Word: Dr. --> Lemmatized Word: Dr.
# Original Word: Brahm --> Lemmatized Word: Brahm
# Original Word: Prakash --> Lemmatized Word: Prakash
# Original Word: father --> Lemmatized Word: father
# Original Word: nuclear --> Lemmatized Word: nuclear
# Original Word: material --> Lemmatized Word: material
# [('I', 'PRP'), ('was', 'VBD'), ('lucky', 'JJ'), ('to', 'TO'), ('have', 'VB'), ('worked', 'VBN'), ('with', 'IN'), ('all', 'DT'), ('three', 'CD'), ('of', 'IN'), ('them', 'PRP'), ('closely', 'RB'), ('and', 'CC'), ('consider', 'VB'), ('this', 'DT'), ('the', 'DT'), ('great', 'JJ'), ('opportunity', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('life', 'NN'), ('.', '.')]
# Original Word: was --> Lemmatized Word: be
# Original Word: lucky --> Lemmatized Word: lucky
# Original Word: have --> Lemmatized Word: have
# Original Word: worked --> Lemmatized Word: work
# Original Word: closely --> Lemmatized Word: closely
# Original Word: consider --> Lemmatized Word: consider
# Original Word: great --> Lemmatized Word: great
# Original Word: opportunity --> Lemmatized Word: opportunity
# Original Word: life --> Lemmatized Word: life
# [('I', 'PRP'), ('was', 'VBD'), ('in', 'IN'), ('Hyderabad', 'NNP'), ('giving', 'VBG'), ('this', 'DT'), ('lecture', 'NN'), (',', ','), ('when', 'WRB'), ('a', 'DT'), ('14', 'CD'), ('year-old', 'JJ'), ('girl', 'NN'), ('asked', 'VBD'), ('me', 'PRP'), ('for', 'IN'), ('my', 'PRP$'), ('autograph', 'NN'), ('.', '.')]
# Original Word: was --> Lemmatized Word: be
# Original Word: Hyderabad --> Lemmatized Word: Hyderabad
# Original Word: giving --> Lemmatized Word: give
# Original Word: lecture --> Lemmatized Word: lecture
# Original Word: year-old --> Lemmatized Word: year-old
# Original Word: girl --> Lemmatized Word: girl
# Original Word: asked --> Lemmatized Word: ask
# Original Word: autograph --> Lemmatized Word: autograph
# [('I', 'PRP'), ('asked', 'VBD'), ('her', 'PRP'), ('what', 'WP'), ('her', 'PRP$'), ('goal', 'NN'), ('in', 'IN'), ('life', 'NN'), ('is', 'VBZ'), ('.', '.')]
# Original Word: asked --> Lemmatized Word: ask
# Original Word: goal --> Lemmatized Word: goal
# Original Word: life --> Lemmatized Word: life
# Original Word: is --> Lemmatized Word: be
# [('She', 'PRP'), ('replied', 'VBD'), (':', ':'), ('I', 'PRP'), ('want', 'VBP'), ('to', 'TO'), ('live', 'VB'), ('in', 'IN'), ('a', 'DT'), ('developed', 'JJ'), ('India', 'NNP'), ('.', '.')]
# Original Word: replied --> Lemmatized Word: reply
# Original Word: want --> Lemmatized Word: want
# Original Word: live --> Lemmatized Word: live
# Original Word: developed --> Lemmatized Word: developed
# Original Word: India --> Lemmatized Word: India
# [('For', 'IN'), ('her', 'PRP$'), (',', ','), ('you', 'PRP'), ('and', 'CC'), ('I', 'PRP'), ('will', 'MD'), ('have', 'VB'), ('to', 'TO'), ('build', 'VB'), ('this', 'DT'), ('developed', 'JJ'), ('India', 'NNP'), ('.', '.')]
# Original Word: have --> Lemmatized Word: have
# Original Word: build --> Lemmatized Word: build
# Original Word: developed --> Lemmatized Word: developed
# Original Word: India --> Lemmatized Word: India
# [('You', 'PRP'), ('must', 'MD'), ('proclaim', 'VB'), ('India', 'NNP'), ('is', 'VBZ'), ('not', 'RB'), ('an', 'DT'), ('underdeveloped', 'JJ'), ('nation', 'NN'), (';', ':'), ('it', 'PRP'), ('is', 'VBZ'), ('a', 'DT'), ('highly', 'RB'), ('developed', 'JJ'), ('nation', 'NN'), ('.', '.')]
# Original Word: proclaim --> Lemmatized Word: proclaim
# Original Word: India --> Lemmatized Word: India
# Original Word: is --> Lemmatized Word: be
# Original Word: not --> Lemmatized Word: not
# Original Word: underdeveloped --> Lemmatized Word: underdeveloped
# Original Word: nation --> Lemmatized Word: nation
# Original Word: is --> Lemmatized Word: be
# Original Word: highly --> Lemmatized Word: highly
# Original Word: developed --> Lemmatized Word: developed
# Original Word: nation --> Lemmatized Word: nation
# [('You', 'PRP'), ('say', 'VBP'), ('that', 'IN'), ('our', 'PRP$'), ('government', 'NN'), ('is', 'VBZ'), ('inefficient', 'JJ'), ('.', '.')]
# Original Word: say --> Lemmatized Word: say
# Original Word: government --> Lemmatized Word: government
# Original Word: is --> Lemmatized Word: be
# Original Word: inefficient --> Lemmatized Word: inefficient
# [('You', 'PRP'), ('say', 'VBP'), ('that', 'IN'), ('our', 'PRP$'), ('laws', 'NNS'), ('are', 'VBP'), ('too', 'RB'), ('old', 'JJ'), ('.', '.')]
# Original Word: say --> Lemmatized Word: say
# Original Word: laws --> Lemmatized Word: law
# Original Word: are --> Lemmatized Word: be
# Original Word: too --> Lemmatized Word: too
# Original Word: old --> Lemmatized Word: old
# [('You', 'PRP'), ('say', 'VBP'), ('that', 'IN'), ('the', 'DT'), ('municipality', 'NN'), ('does', 'VBZ'), ('not', 'RB'), ('pick', 'VB'), ('up', 'RP'), ('the', 'DT'), ('garbage', 'NN'), ('.', '.')]
# Original Word: say --> Lemmatized Word: say
# Original Word: municipality --> Lemmatized Word: municipality
# Original Word: does --> Lemmatized Word: do
# Original Word: not --> Lemmatized Word: not
# Original Word: pick --> Lemmatized Word: pick
# Original Word: garbage --> Lemmatized Word: garbage
# [('You', 'PRP'), ('say', 'VBP'), ('that', 'IN'), ('the', 'DT'), ('phones', 'NNS'), ('don', 'VBP'), ('’', 'JJ'), ('t', 'NN'), ('work', 'NN'), (',', ','), ('the', 'DT'), ('railways', 'NNS'), ('are', 'VBP'), ('a', 'DT'), ('joke', 'NN'), (',', ','), ('the', 'DT'), ('airline', 'NN'), ('is', 'VBZ'), ('the', 'DT'), ('worst', 'JJS'), ('in', 'IN'), ('the', 'DT'), ('world', 'NN'), (',', ','), ('and', 'CC'), ('mails', 'NNS'), ('never', 'RB'), ('reach', 'VBP'), ('their', 'PRP$'), ('destination', 'NN'), ('.', '.')]
# Original Word: say --> Lemmatized Word: say
# Original Word: phones --> Lemmatized Word: phone
# Original Word: don --> Lemmatized Word: don
# Original Word: ’ --> Lemmatized Word: ’
# Original Word: t --> Lemmatized Word: t
# Original Word: work --> Lemmatized Word: work
# Original Word: railways --> Lemmatized Word: railway
# Original Word: are --> Lemmatized Word: be
# Original Word: joke --> Lemmatized Word: joke
# Original Word: airline --> Lemmatized Word: airline
# Original Word: is --> Lemmatized Word: be
# Original Word: worst --> Lemmatized Word: bad
# Original Word: world --> Lemmatized Word: world
# Original Word: mails --> Lemmatized Word: mail
# Original Word: never --> Lemmatized Word: never
# Original Word: reach --> Lemmatized Word: reach
# Original Word: destination --> Lemmatized Word: destination
# [('You', 'PRP'), ('say', 'VBP'), ('that', 'IN'), ('our', 'PRP$'), ('country', 'NN'), ('has', 'VBZ'), ('been', 'VBN'), ('fed', 'VBN'), ('to', 'TO'), ('the', 'DT'), ('dogs', 'NNS'), ('and', 'CC'), ('is', 'VBZ'), ('the', 'DT'), ('absolute', 'JJ'), ('pits', 'NNS'), ('.', '.')]
# Original Word: say --> Lemmatized Word: say
# Original Word: country --> Lemmatized Word: country
# Original Word: has --> Lemmatized Word: have
# Original Word: been --> Lemmatized Word: be
# Original Word: fed --> Lemmatized Word: feed
# Original Word: dogs --> Lemmatized Word: dog
# Original Word: is --> Lemmatized Word: be
# Original Word: absolute --> Lemmatized Word: absolute
# Original Word: pits --> Lemmatized Word: pit
# [('You', 'PRP'), ('say', 'VBP'), (',', ','), ('say', 'VBP'), ('and', 'CC'), ('say', 'VBP'), ('.', '.')]
# Original Word: say --> Lemmatized Word: say
# Original Word: say --> Lemmatized Word: say
# Original Word: say --> Lemmatized Word: say
# [('What', 'WP'), ('do', 'VBP'), ('you', 'PRP'), ('do', 'VB'), ('about', 'IN'), ('it', 'PRP'), ('?', '.')]
# Original Word: do --> Lemmatized Word: do
# Original Word: do --> Lemmatized Word: do
# [('Dear', 'NNP'), ('Indians', 'NNPS'), (',', ','), ('I', 'PRP'), ('am', 'VBP'), ('echoing', 'VBG'), ('J.F.Kennedy', 'NNP'), ('’', 'NNP'), ('s', 'NN'), ('words', 'NNS'), ('to', 'TO'), ('his', 'PRP$'), ('fellow', 'JJ'), ('Americans', 'NNPS'), ('to', 'TO'), ('relate', 'VB'), ('to', 'TO'), ('Indians', 'NNPS'), ('……', 'NNP'), ('.', '.')]
# Original Word: Dear --> Lemmatized Word: Dear
# Original Word: Indians --> Lemmatized Word: Indians
# Original Word: am --> Lemmatized Word: be
# Original Word: echoing --> Lemmatized Word: echo
# Original Word: J.F.Kennedy --> Lemmatized Word: J.F.Kennedy
# Original Word: ’ --> Lemmatized Word: ’
# Original Word: s --> Lemmatized Word: s
# Original Word: words --> Lemmatized Word: word
# Original Word: fellow --> Lemmatized Word: fellow
# Original Word: Americans --> Lemmatized Word: Americans
# Original Word: relate --> Lemmatized Word: relate
# Original Word: Indians --> Lemmatized Word: Indians
# Original Word: …… --> Lemmatized Word: ……
# [('“', 'NN'), ('ASK', 'NNP'), ('WHAT', 'NNP'), ('WE', 'NNP'), ('CAN', 'NNP'), ('DO', 'NNP'), ('FOR', 'NNP'), ('INDIA', 'NNP'), ('AND', 'NNP'), ('DO', 'NNP'), ('WHAT', 'NNP'), ('HAS', 'NNP'), ('TO', 'NNP'), ('BE', 'NNP'), ('DONE', 'NNP'), ('TO', 'NNP'), ('MAKE', 'NNP'), ('INDIA', 'NNP'), ('WHAT', 'NNP'), ('AMERICA', 'NNP'), ('AND', 'NNP'), ('OTHER', 'NNP'), ('WESTERN', 'NNP'), ('COUNTRIES', 'NNP'), ('ARE', 'NNP'), ('TODAY', 'NNP'), ('.', '.'), ('”', 'NN')]
# Original Word: “ --> Lemmatized Word: “
# Original Word: ASK --> Lemmatized Word: ASK
# Original Word: WHAT --> Lemmatized Word: WHAT
# Original Word: WE --> Lemmatized Word: WE
# Original Word: CAN --> Lemmatized Word: CAN
# Original Word: DO --> Lemmatized Word: DO
# Original Word: FOR --> Lemmatized Word: FOR
# Original Word: INDIA --> Lemmatized Word: INDIA
# Original Word: AND --> Lemmatized Word: AND
# Original Word: DO --> Lemmatized Word: DO
# Original Word: WHAT --> Lemmatized Word: WHAT
# Original Word: HAS --> Lemmatized Word: HAS
# Original Word: TO --> Lemmatized Word: TO
# Original Word: BE --> Lemmatized Word: BE
# Original Word: DONE --> Lemmatized Word: DONE
# Original Word: TO --> Lemmatized Word: TO
# Original Word: MAKE --> Lemmatized Word: MAKE
# Original Word: INDIA --> Lemmatized Word: INDIA
# Original Word: WHAT --> Lemmatized Word: WHAT
# Original Word: AMERICA --> Lemmatized Word: AMERICA
# Original Word: AND --> Lemmatized Word: AND
# Original Word: OTHER --> Lemmatized Word: OTHER
# Original Word: WESTERN --> Lemmatized Word: WESTERN
# Original Word: COUNTRIES --> Lemmatized Word: COUNTRIES
# Original Word: ARE --> Lemmatized Word: ARE
# Original Word: TODAY --> Lemmatized Word: TODAY
# Original Word: ” --> Lemmatized Word: ”

# %%
sen = "India got its first vision of this in 1857, when we started the war of Independence, developed."
sen_words = nltk.word_tokenize(sen)
sen_pos_tag = nltk.pos_tag(sen_words)

# %%
lemmatizer.lemmatize("developed",'v')
# Out:
# 'develop'
